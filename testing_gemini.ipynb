# %%
from clients import GeminiClient

# %%
# Default is the flash-lite model
gc = GeminiClient()

# Next model up:
#gc = GeminiClient(GeminiClient.Models.FLASH)

# Pro model:
#gc = GeminiClient(GeminiClient.Models.PRO)

# %%
gc.set_request("""
I'm reading Hunger Games.
Provide your top 10 words that characterize the theme of the book 
with regards to musical genres.

Provide the output in the format of Python list.
""")

# %%
gc.get_request()
# Out:
# ['/opt/homebrew/bin/gemini',
#  '--model',
#  'gemini-2.5-flash-lite',
#  '--output-format',
#  'json',
#  '--prompt',
#  "\nI'm reading Hunger Games.\nProvide your top 10 words that characterize the theme of the book \nwith regards to musical genres.\n\nProvide the output in the format of Python list.\n"]

# %%
gc.send_request()
# Out:
# --------------------------------------------------
# 2025-11-12 14:07:28.355969: Running: ['/opt/homebrew/bin/gemini', '--model', 'gemini-2.5-flash-lite', '--output-format', 'json', '--prompt', "\nI'm reading Hunger Games.\nProvide your top 10 words that characterize the theme of the book \nwith regards to musical genres.\n\nProvide the output in the format of Python list.\n"]
# --------------------------------------------------
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /var/folders/mt/fzq0xrj11g1ftyy3chjz6x200000gn/T/ipykernel_63167/1145323398.py in <module>
# ----> 1 gc.send_request()
#
# ~/Desktop/gity/DATA-440-Final/clients.py in send_request(self)
#      74         t0 = dt.now()
#      75         print(f'{LINE_BREAK}{t0}: Running: {self._request}\n{LINE_BREAK}')
# ---> 76         self._result = subprocess.run(self._request, capture_output=True, text=True, check=True)
#      77         print(f'Finished at {dt.now()}. Runtime: {dt.now()-t0}\n{LINE_BREAK}')
#      78         return None
#
# ~/opt/anaconda3/lib/python3.9/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     526         retcode = process.poll()
#     527         if check and retcode:
# --> 528             raise CalledProcessError(retcode, process.args,
#     529                                      output=stdout, stderr=stderr)
#     530     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['/opt/homebrew/bin/gemini', '--model', 'gemini-2.5-flash-lite', '--output-format', 'json', '--prompt', "\nI'm reading Hunger Games.\nProvide your top 10 words that characterize the theme of the book \nwith regards to musical genres.\n\nProvide the output in the format of Python list.\n"]' returned non-zero exit status 1.

# %%
print(gc.get_result()['response'])

# %%
print(gc.get_result()['stats'])
